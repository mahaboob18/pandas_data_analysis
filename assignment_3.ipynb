# %%
import pandas as pd

# %%
sales_data=pd.read_csv(r"C:\Users\mahab\Downloads\Telegram Desktop\sales_dataset.csv")

# %%
sales_data.isnull().sum()
# Out:
# Order_ID         0
# Customer_Name    0
# Region           5
# Product          0
# Units_Sold       4
# Unit_Price       0
# Total_Sales      6
# Discount         0
# dtype: int64

# %%
sales_data.shape
# Out:
# (30, 8)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       30 non-null     int64
#  1   Customer_Name  30 non-null     object
#  2   Region         25 non-null     object
#  3   Product        30 non-null     object
#  4   Units_Sold     26 non-null     float64
#  5   Unit_Price     30 non-null     int64
#  6   Total_Sales    24 non-null     float64
#  7   Discount       30 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 2.0+ KB

# %% [markdown]
# #### Identify the columns with missing values and their counts. Propose suitableimputation methods for each.

# %%
sales_data.isnull().sum()
# Out:
# Order_ID         0
# Customer_Name    0
# Region           5
# Product          0
# Units_Sold       4
# Unit_Price       0
# Total_Sales      6
# Discount         0
# dtype: int64

# %%
# cols with atleast one missing values 

sales_data.isnull().any()
# Out:
# Order_ID         False
# Customer_Name    False
# Region            True
# Product          False
# Units_Sold        True
# Unit_Price       False
# Total_Sales       True
# Discount         False
# dtype: bool

# %%
# cols with all missing
sales_data.isnull().all()
# Out:
# Order_ID         False
# Customer_Name    False
# Region           False
# Product          False
# Units_Sold       False
# Unit_Price       False
# Total_Sales      False
# Discount         False
# dtype: bool

# %%
# numbers of cols with any one missing value
sales_data
# Out:
#     Order_ID Customer_Name Region    Product  Units_Sold  Unit_Price  \
# 0          1    Customer_1   East  Product_A         9.0          25
# 1          2    Customer_2   West  Product_A        26.0          10
# 2          3    Customer_3  North  Product_B         2.0          30
# 3          4    Customer_4   East  Product_B        20.0          30
# 4          5    Customer_5   East  Product_A        28.0          15
# 5          6    Customer_6   West  Product_A        47.0          30
# 6          7    Customer_7  North  Product_A         7.0          15
# 7          8    Customer_8  North  Product_C        44.0          10
# 8          9    Customer_9   East  Product_C         NaN          25
# 9         10   Customer_10  South  Product_C        47.0          25
# 10        11   Customer_11   East  Product_B         NaN          25
# 11        12   Customer_12   East  Product_C        14.0          30
# 12        13   Customer_13   East  Product_B        17.0          10
# ...

# %%
# rows with atleast one missing values 

sales_data.isnull().any(axis=1)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18    False
# 19    False
# 20     True
# 21    False
# 22     True
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29     True
# dtype: bool

# %%
# numbers of rows with any missing values
sales_data.isnull().any(axis=1).sum()
# Out:
# 12

# %%
# percentage of the column
sales_data.isnull().sum()/len(ss)
# Out:
# Order_ID         0.000000
# Customer_Name    0.000000
# Region           0.166667
# Product          0.000000
# Units_Sold       0.133333
# Unit_Price       0.000000
# Total_Sales      0.200000
# Discount         0.000000
# dtype: float64

# %%
# dropping a column
sales_data.drop(columns=["Total_Sales","Region"])
# Out:
#     Order_ID Customer_Name    Product  Units_Sold  Unit_Price  Discount
# 0          1    Customer_1  Product_A         9.0          25         0
# 1          2    Customer_2  Product_A        26.0          10         5
# 2          3    Customer_3  Product_B         2.0          30         0
# 3          4    Customer_4  Product_B        20.0          30         0
# 4          5    Customer_5  Product_A        28.0          15         0
# 5          6    Customer_6  Product_A        47.0          30        10
# 6          7    Customer_7  Product_A         7.0          15         0
# 7          8    Customer_8  Product_C        44.0          10         0
# 8          9    Customer_9  Product_C         NaN          25         5
# 9         10   Customer_10  Product_C        47.0          25         0
# 10        11   Customer_11  Product_B         NaN          25         5
# 11        12   Customer_12  Product_C        14.0          30         0
# ...

# %% [markdown]
# #### Impute missing values in the Region column with 'Unknown' and in the Units_Sold olumn using the median value.

# %%
# fill the col with constant value
sales_data["Region"].fillna("unknown")
# Out:
# 0        East
# 1        West
# 2       North
# 3        East
# 4        East
# 5        West
# 6       North
# 7       North
# 8        East
# 9       South
# 10       East
# 11       East
# 12       East
# 13       East
# 14       West
# 15      North
# 16    unknown
# 17    unknown
# 18       West
# 19       East
# 20    unknown
# 21      North
# 22      South
# 23       West
# 24       West
# 25    unknown
# 26      South
# 27      South
# 28       West
# 29    unknown
# Name: Region, dtype: object

# %%
# statistical imputation
sales_data["Units_Sold"].fillna(ss["Total_Sales"].median())
# Out:
# 0        9.0
# 1       26.0
# 2        2.0
# 3       20.0
# 4       28.0
# 5       47.0
# 6        7.0
# 7       44.0
# 8     1245.5
# 9       47.0
# 10    1245.5
# 11      14.0
# 12      17.0
# 13    1245.5
# 14      40.0
# 15       4.0
# 16       2.0
# 17       6.0
# 18      42.0
# 19       4.0
# 20      29.0
# 21      18.0
# 22    1245.5
# 23      44.0
# 24      34.0
# 25      10.0
# 26      36.0
# 27      14.0
# 28     200.0
# 29     300.0
# Name: Units_Sold, dtype: float64

# %%
sales_data.dropna(subset=["Region"])
# Out:
#     Order_ID Customer_Name Region    Product  Units_Sold  Unit_Price  \
# 0          1    Customer_1   East  Product_A         9.0          25
# 1          2    Customer_2   West  Product_A        26.0          10
# 2          3    Customer_3  North  Product_B         2.0          30
# 3          4    Customer_4   East  Product_B        20.0          30
# 4          5    Customer_5   East  Product_A        28.0          15
# 5          6    Customer_6   West  Product_A        47.0          30
# 6          7    Customer_7  North  Product_A         7.0          15
# 7          8    Customer_8  North  Product_C        44.0          10
# 8          9    Customer_9   East  Product_C         NaN          25
# 9         10   Customer_10  South  Product_C        47.0          25
# 10        11   Customer_11   East  Product_B         NaN          25
# 11        12   Customer_12   East  Product_C        14.0          30
# 12        13   Customer_13   East  Product_B        17.0          10
# ...

# %%
len(sales_data.dropna(subset=["Region"]))
# Out:
# 25

# %%
sales_data["Total_Sales"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# ####  Detect outliers in the Units_Sold column using the IQR method. What are the lower and upper bound

# %%
sales_data["Units_Sold"].plot(kind="box")
# Out:
# <Axes: >

# %%
## finding upper boundary and lower boundary
#sales_data["Units_Sold"].plot(kind="box")
q1=sales_data["Units_Sold"].quantile(0.25)
q3=sales_data["Units_Sold"].quantile(0.75) 
iqr=q3=q1
 
upper_bound=q3+(1.5*iqr) 

lower_bound=q1-(1.5*iqr)
print("lower bound  value is : ",lower_bound)
print("upper bound value is : ",upper_bound)
# Out:
# lower bound  value is :  -4.625
# upper bound value is :  23.125

# %%
sales_data=sales_data[(sales_data["Units_Sold"]>=lower_bound) & (sales_data["Units_Sold"]<=upper_bound)]

# %% [markdown]
# ####  Visualize the outliers using a box plot before and after treatment.

# %%
sales_data["Units_Sold"].plot(kind="box")
# Out:
# <Axes: >
